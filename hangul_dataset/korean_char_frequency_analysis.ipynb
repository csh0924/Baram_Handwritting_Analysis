# %%
import json
import re
from pathlib import Path
from collections import Counter
from typing import Iterable, Tuple, Optional,  Dict, List
import csv
from dataclasses import dataclass

# %%
HANGUL_SYLLABLE_RE = re.compile(r"[가-힣]")

# %%
def iter_content_sentences_from_file(json_path: Path) -> Iterable[str]:
    try:
        with open(json_path, "r", encoding="utf-8") as f:
            data = json.load(f)
    except Exception as e:
        print(f"[WARN] failed to read {json_path}: {e}")
        return

    named_entity = data.get("named_entity")
    if not isinstance(named_entity, list):
        return

    for ne in named_entity:
        if not isinstance(ne, dict):
            continue
        content = ne.get("content")
        if not isinstance(content, list):
            continue
        for item in content:
            if not isinstance(item, dict):
                continue
            s = item.get("sentence")
            if isinstance(s, str) and s:
                yield s

# %%
def iter_json_files_recursive(root_dir: Path) -> Iterable[Path]:
    yield from root_dir.rglob("*.json")

# %%
def count_hangul_syllables_from_root(root_dir: Path) -> Tuple[Counter, int, int]:
    counter = Counter()
    total_chars = 0
    processed = 0

    for jp in iter_json_files_recursive(root_dir):
        processed += 1
        for sent in iter_content_sentences_from_file(jp):
            chars = HANGUL_SYLLABLE_RE.findall(sent)
            counter.update(chars)
            total_chars += len(chars)

        if processed % 200 == 0:
            print(f"...processed {processed} files, total_hangul_chars={total_chars:,}, unique={len(counter):,}")

    return counter, total_chars, processed

# %%
def print_top(counter: Counter, k: int = 50):
    for ch, c in counter.most_common(k):
        print(f"{ch}\t{c}")

# %%
root_dir = Path(r"D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\030.웹데이터 기반 한국어 말뭉치 데이터\01.데이터\1.Training\라벨링데이터\TL1")  
top_k = 100

counter, total_chars, n_files = count_hangul_syllables_from_root(root_dir)

print("\n===== SUMMARY =====")
print("Root:", root_dir)
print("JSON files processed:", n_files)
print("Total Hangul syllables:", f"{total_chars:,}")
print("Unique Hangul syllables:", f"{len(counter):,}")

print(f"\n===== TOP {top_k} =====")
print_top(counter, top_k)
# Out:
# ...processed 200 files, total_hangul_chars=13,202,615, unique=1,674
# ...processed 400 files, total_hangul_chars=26,680,904, unique=1,779
# ...processed 600 files, total_hangul_chars=41,687,496, unique=1,862
# ...processed 800 files, total_hangul_chars=62,098,610, unique=2,023
# ...processed 1000 files, total_hangul_chars=83,916,818, unique=2,146
# ...processed 1200 files, total_hangul_chars=101,193,942, unique=2,211
# ...processed 1400 files, total_hangul_chars=112,820,723, unique=2,229
# ...processed 1600 files, total_hangul_chars=125,048,484, unique=2,258
# ...processed 1800 files, total_hangul_chars=133,398,476, unique=2,265
# ...processed 2000 files, total_hangul_chars=143,718,479, unique=2,268
# ...processed 2200 files, total_hangul_chars=154,830,040, unique=2,275
# ...processed 2400 files, total_hangul_chars=164,775,948, unique=2,278
# ...processed 2600 files, total_hangul_chars=175,092,235, unique=2,283
# ...processed 2800 files, total_hangul_chars=187,753,025, unique=2,289
# ...processed 3000 files, total_hangul_chars=201,215,082, unique=2,293
# ...processed 3200 files, total_hangul_chars=211,533,739, unique=2,300
# ...processed 3400 files, total_hangul_chars=221,662,805, unique=2,306
# ...processed 3600 files, total_hangul_chars=230,732,300, unique=2,310
# ...processed 3800 files, total_hangul_chars=239,862,732, unique=2,317
# ...processed 4000 files, total_hangul_chars=247,591,961, unique=2,321
# ...processed 4200 files, total_hangul_chars=254,619,837, unique=2,322
# ...processed 4400 files, total_hangul_chars=269,020,329, unique=2,341
# ...processed 4600 files, total_hangul_chars=280,596,749, unique=2,350
# ...processed 4800 files, total_hangul_chars=291,176,186, unique=2,352
# ...processed 5000 files, total_hangul_chars=303,573,628, unique=2,352
# ...processed 5200 files, total_hangul_chars=314,829,288, unique=2,353
# ...processed 5400 files, total_hangul_chars=327,739,127, unique=2,356
# ...processed 5600 files, total_hangul_chars=339,365,144, unique=2,364
# ...processed 5800 files, total_hangul_chars=351,090,411, unique=2,368
# ...processed 6000 files, total_hangul_chars=364,433,322, unique=2,376
# ...processed 6200 files, total_hangul_chars=372,273,289, unique=2,378
# ...processed 6400 files, total_hangul_chars=383,948,993, unique=2,379
# ...processed 6600 files, total_hangul_chars=395,299,883, unique=2,379
# ...processed 6800 files, total_hangul_chars=405,225,577, unique=2,380
# ...processed 7000 files, total_hangul_chars=409,701,352, unique=2,381
# ...processed 7200 files, total_hangul_chars=413,857,888, unique=2,381
# ...processed 7400 files, total_hangul_chars=417,786,204, unique=2,383
# ...processed 7600 files, total_hangul_chars=421,742,554, unique=2,383
# ...processed 7800 files, total_hangul_chars=427,373,013, unique=2,383
# ...processed 8000 files, total_hangul_chars=435,728,344, unique=2,384
# ...processed 8200 files, total_hangul_chars=444,393,708, unique=2,385
# ...processed 8400 files, total_hangul_chars=449,838,359, unique=2,385
# ...processed 8600 files, total_hangul_chars=457,446,598, unique=2,385
# ...processed 8800 files, total_hangul_chars=466,321,601, unique=2,387
# ...processed 9000 files, total_hangul_chars=478,040,047, unique=2,389
# ...processed 9200 files, total_hangul_chars=491,484,389, unique=2,392
# ...processed 9400 files, total_hangul_chars=505,023,460, unique=2,394
# ...processed 9600 files, total_hangul_chars=519,778,378, unique=2,399
# ...processed 9800 files, total_hangul_chars=533,518,144, unique=2,400
# ...processed 10000 files, total_hangul_chars=546,280,780, unique=2,402
# ...processed 10200 files, total_hangul_chars=558,603,197, unique=2,402
# ...processed 10400 files, total_hangul_chars=569,165,866, unique=2,402
# ...processed 10600 files, total_hangul_chars=579,282,202, unique=2,402
# ...processed 10800 files, total_hangul_chars=588,349,964, unique=2,406
# ...processed 11000 files, total_hangul_chars=597,919,210, unique=2,408
# ...processed 11200 files, total_hangul_chars=607,459,296, unique=2,410
# ...processed 11400 files, total_hangul_chars=617,434,100, unique=2,411
# ...processed 11600 files, total_hangul_chars=628,241,149, unique=2,411
# ...processed 11800 files, total_hangul_chars=636,094,344, unique=2,412
# ...processed 12000 files, total_hangul_chars=644,721,133, unique=2,412
# ...processed 12200 files, total_hangul_chars=653,743,592, unique=2,413
# ...processed 12400 files, total_hangul_chars=663,593,262, unique=2,414
# ...processed 12600 files, total_hangul_chars=670,838,882, unique=2,415
# ...processed 12800 files, total_hangul_chars=682,177,736, unique=2,415
# ...processed 13000 files, total_hangul_chars=694,022,989, unique=2,417
# ...processed 13200 files, total_hangul_chars=707,412,241, unique=2,418
# ...processed 13400 files, total_hangul_chars=719,475,599, unique=2,419
# ...processed 13600 files, total_hangul_chars=730,768,439, unique=2,419
# ...processed 13800 files, total_hangul_chars=743,022,744, unique=2,420
# ...processed 14000 files, total_hangul_chars=753,472,765, unique=2,422
# ...processed 14200 files, total_hangul_chars=764,116,727, unique=2,423
# ...processed 14400 files, total_hangul_chars=774,437,057, unique=2,423
# ...processed 14600 files, total_hangul_chars=791,253,514, unique=2,469
# ...processed 14800 files, total_hangul_chars=807,401,625, unique=2,746
# ...processed 15000 files, total_hangul_chars=815,110,817, unique=2,748
# ...processed 15200 files, total_hangul_chars=821,134,203, unique=2,749
# ...processed 15400 files, total_hangul_chars=828,267,547, unique=2,749
# ...processed 15600 files, total_hangul_chars=838,400,010, unique=2,749
# ...processed 15800 files, total_hangul_chars=851,806,566, unique=2,749
# ...processed 16000 files, total_hangul_chars=865,389,203, unique=2,750
# ...processed 16200 files, total_hangul_chars=874,819,728, unique=2,751
# ...processed 16400 files, total_hangul_chars=884,268,715, unique=2,751
# ...processed 16600 files, total_hangul_chars=894,527,175, unique=2,751
# ...processed 16800 files, total_hangul_chars=904,947,905, unique=2,752
# ...processed 17000 files, total_hangul_chars=914,625,230, unique=2,753
# ...processed 17200 files, total_hangul_chars=924,968,642, unique=2,753
# ...processed 17400 files, total_hangul_chars=934,501,965, unique=2,753
# ...processed 17600 files, total_hangul_chars=951,388,953, unique=2,779
# ...processed 17800 files, total_hangul_chars=965,017,348, unique=2,781
# ...processed 18000 files, total_hangul_chars=980,528,569, unique=2,782
# ...processed 18200 files, total_hangul_chars=994,742,664, unique=2,791
# ...processed 18400 files, total_hangul_chars=1,007,904,102, unique=2,793
# ...processed 18600 files, total_hangul_chars=1,016,200,988, unique=2,794
# ...processed 18800 files, total_hangul_chars=1,025,932,737, unique=2,794
# ...processed 19000 files, total_hangul_chars=1,037,298,788, unique=2,795
# ...processed 19200 files, total_hangul_chars=1,047,501,761, unique=2,796
# ...processed 19400 files, total_hangul_chars=1,060,033,527, unique=2,796
# ...processed 19600 files, total_hangul_chars=1,073,570,449, unique=2,797
# ...processed 19800 files, total_hangul_chars=1,089,297,559, unique=2,797
# ...processed 20000 files, total_hangul_chars=1,100,247,044, unique=2,797
# ...processed 20200 files, total_hangul_chars=1,107,725,964, unique=2,797
# ...processed 20400 files, total_hangul_chars=1,115,585,616, unique=2,799
# ...processed 20600 files, total_hangul_chars=1,124,274,293, unique=2,799
# ...processed 20800 files, total_hangul_chars=1,134,346,585, unique=2,799
# ...processed 21000 files, total_hangul_chars=1,143,785,402, unique=2,800
# ...processed 21200 files, total_hangul_chars=1,157,034,009, unique=2,800
# ...processed 21400 files, total_hangul_chars=1,170,929,717, unique=2,800
# ...processed 21600 files, total_hangul_chars=1,184,868,573, unique=2,800
# ...processed 21800 files, total_hangul_chars=1,198,381,209, unique=2,801
# ...processed 22000 files, total_hangul_chars=1,208,280,933, unique=2,801
# ...processed 22200 files, total_hangul_chars=1,216,737,142, unique=2,802
# ...processed 22400 files, total_hangul_chars=1,225,302,124, unique=2,802
# ...processed 22600 files, total_hangul_chars=1,235,933,027, unique=2,802
# ...processed 22800 files, total_hangul_chars=1,246,815,718, unique=2,802
# ...processed 23000 files, total_hangul_chars=1,258,706,431, unique=2,802
# ...processed 23200 files, total_hangul_chars=1,273,052,532, unique=2,802
# ...processed 23400 files, total_hangul_chars=1,286,923,199, unique=2,803
# ...processed 23600 files, total_hangul_chars=1,298,823,190, unique=2,806
# ...processed 23800 files, total_hangul_chars=1,309,658,663, unique=2,807
# ...processed 24000 files, total_hangul_chars=1,321,929,706, unique=2,807
# ...processed 24200 files, total_hangul_chars=1,335,589,108, unique=2,808
# ...processed 24400 files, total_hangul_chars=1,347,835,041, unique=2,808
# ...processed 24600 files, total_hangul_chars=1,358,392,456, unique=2,808
# ...processed 24800 files, total_hangul_chars=1,367,334,680, unique=2,808
# ...processed 25000 files, total_hangul_chars=1,376,433,271, unique=2,808
# ...processed 25200 files, total_hangul_chars=1,385,526,974, unique=2,808
# ...processed 25400 files, total_hangul_chars=1,393,848,340, unique=2,808
# ...processed 25600 files, total_hangul_chars=1,406,192,367, unique=2,809
# ...processed 25800 files, total_hangul_chars=1,417,533,460, unique=2,809
# ...processed 26000 files, total_hangul_chars=1,429,863,100, unique=2,810
# ...processed 26200 files, total_hangul_chars=1,440,040,706, unique=2,810
# ...processed 26400 files, total_hangul_chars=1,452,030,903, unique=2,810
# ...processed 26600 files, total_hangul_chars=1,464,705,722, unique=2,810
# ...processed 26800 files, total_hangul_chars=1,477,436,255, unique=2,810
# ...processed 27000 files, total_hangul_chars=1,489,324,170, unique=2,810
# ...processed 27200 files, total_hangul_chars=1,501,460,440, unique=2,811
# ...processed 27400 files, total_hangul_chars=1,514,768,803, unique=2,812
# ...processed 27600 files, total_hangul_chars=1,528,369,653, unique=2,812
# ...processed 27800 files, total_hangul_chars=1,541,149,727, unique=2,813
# ...processed 28000 files, total_hangul_chars=1,552,717,649, unique=2,813
# ...processed 28200 files, total_hangul_chars=1,563,855,713, unique=2,815
# ...processed 28400 files, total_hangul_chars=1,574,570,856, unique=2,815
# ...processed 28600 files, total_hangul_chars=1,586,680,248, unique=2,815
# ...processed 28800 files, total_hangul_chars=1,599,190,356, unique=2,815
# ...processed 29000 files, total_hangul_chars=1,612,809,777, unique=2,815
# ...processed 29200 files, total_hangul_chars=1,626,376,300, unique=2,815
# ...processed 29400 files, total_hangul_chars=1,638,450,065, unique=2,815
# ...processed 29600 files, total_hangul_chars=1,648,483,535, unique=2,815
# ...processed 29800 files, total_hangul_chars=1,660,703,927, unique=2,815
# ...processed 30000 files, total_hangul_chars=1,672,145,658, unique=2,815
# ...processed 30200 files, total_hangul_chars=1,683,571,727, unique=2,815
# ...processed 30400 files, total_hangul_chars=1,697,025,575, unique=2,816
# ...processed 30600 files, total_hangul_chars=1,709,224,207, unique=2,816
# ...processed 30800 files, total_hangul_chars=1,721,698,057, unique=2,816
# ...processed 31000 files, total_hangul_chars=1,735,218,467, unique=2,817
# ...processed 31200 files, total_hangul_chars=1,746,664,543, unique=2,818
# ...processed 31400 files, total_hangul_chars=1,757,955,506, unique=2,818
# ...processed 31600 files, total_hangul_chars=1,769,184,420, unique=2,818
# ...processed 31800 files, total_hangul_chars=1,780,381,844, unique=2,818
# ...processed 32000 files, total_hangul_chars=1,791,584,285, unique=2,818
# ...processed 32200 files, total_hangul_chars=1,802,399,101, unique=2,818
# ...processed 32400 files, total_hangul_chars=1,812,195,855, unique=2,818
# ...processed 32600 files, total_hangul_chars=1,822,839,520, unique=2,818
# ...processed 32800 files, total_hangul_chars=1,834,124,032, unique=2,818
# ...processed 33000 files, total_hangul_chars=1,843,899,941, unique=2,818
# ...processed 33200 files, total_hangul_chars=1,852,259,297, unique=2,818
# ...processed 33400 files, total_hangul_chars=1,861,517,514, unique=2,819
# ...processed 33600 files, total_hangul_chars=1,871,041,172, unique=2,819
# ...processed 33800 files, total_hangul_chars=1,880,197,409, unique=2,820
# ...processed 34000 files, total_hangul_chars=1,888,463,062, unique=2,820
# ...processed 34200 files, total_hangul_chars=1,895,007,377, unique=2,820
# ...processed 34400 files, total_hangul_chars=1,902,391,930, unique=2,820
# ...processed 34600 files, total_hangul_chars=1,910,403,814, unique=2,820
# ...processed 34800 files, total_hangul_chars=1,921,041,369, unique=2,820
# ...processed 35000 files, total_hangul_chars=1,935,281,427, unique=2,821
# ...processed 35200 files, total_hangul_chars=1,947,403,357, unique=2,821
# ...processed 35400 files, total_hangul_chars=1,959,334,720, unique=2,821
# ...processed 35600 files, total_hangul_chars=1,972,602,205, unique=2,822
# ...processed 35800 files, total_hangul_chars=1,986,238,470, unique=2,822
# ...processed 36000 files, total_hangul_chars=1,999,432,762, unique=2,822
# ...processed 36200 files, total_hangul_chars=2,011,110,116, unique=2,823
# ...processed 36400 files, total_hangul_chars=2,022,290,951, unique=2,823
# ...processed 36600 files, total_hangul_chars=2,033,523,708, unique=2,823
# ...processed 36800 files, total_hangul_chars=2,046,238,474, unique=2,823
# ...processed 37000 files, total_hangul_chars=2,058,892,003, unique=2,823
# ...processed 37200 files, total_hangul_chars=2,071,259,310, unique=2,823
# ...processed 37400 files, total_hangul_chars=2,083,655,554, unique=2,823
# ...processed 37600 files, total_hangul_chars=2,096,577,904, unique=2,823
# ...processed 37800 files, total_hangul_chars=2,108,678,637, unique=2,823
# ...processed 38000 files, total_hangul_chars=2,118,582,422, unique=2,823
# ...processed 38200 files, total_hangul_chars=2,126,990,706, unique=2,823
# ...processed 38400 files, total_hangul_chars=2,135,627,481, unique=2,823
# ...processed 38600 files, total_hangul_chars=2,142,654,554, unique=2,824
# ...processed 38800 files, total_hangul_chars=2,153,131,197, unique=2,825
# ...processed 39000 files, total_hangul_chars=2,166,454,895, unique=2,827
# ...processed 39200 files, total_hangul_chars=2,175,190,559, unique=2,828
# ...processed 39400 files, total_hangul_chars=2,185,124,212, unique=2,828
# ...processed 39600 files, total_hangul_chars=2,196,785,373, unique=2,828
# ...processed 39800 files, total_hangul_chars=2,205,568,616, unique=2,829
# ...processed 40000 files, total_hangul_chars=2,217,608,448, unique=2,829
# ...processed 40200 files, total_hangul_chars=2,228,683,169, unique=2,829
# ...processed 40400 files, total_hangul_chars=2,238,612,060, unique=2,830
# ...processed 40600 files, total_hangul_chars=2,250,521,213, unique=2,830
# ...processed 40800 files, total_hangul_chars=2,261,908,439, unique=2,831
# ...processed 41000 files, total_hangul_chars=2,270,971,478, unique=2,831
# ...processed 41200 files, total_hangul_chars=2,280,445,852, unique=2,831
# ...processed 41400 files, total_hangul_chars=2,289,291,196, unique=2,832
# ...processed 41600 files, total_hangul_chars=2,298,983,401, unique=2,832
# ...processed 41800 files, total_hangul_chars=2,310,344,798, unique=2,833
# ...processed 42000 files, total_hangul_chars=2,321,505,334, unique=2,833
# ...processed 42200 files, total_hangul_chars=2,330,186,365, unique=2,834
# ...processed 42400 files, total_hangul_chars=2,340,276,327, unique=2,834
# ...processed 42600 files, total_hangul_chars=2,349,857,462, unique=2,834
# ...processed 42800 files, total_hangul_chars=2,361,691,364, unique=2,834
# ...processed 43000 files, total_hangul_chars=2,375,042,057, unique=2,834
# ...processed 43200 files, total_hangul_chars=2,389,280,916, unique=2,835
# ...processed 43400 files, total_hangul_chars=2,404,663,981, unique=2,835
# ...processed 43600 files, total_hangul_chars=2,419,293,370, unique=2,835
# ...processed 43800 files, total_hangul_chars=2,434,476,018, unique=2,835
# ...processed 44000 files, total_hangul_chars=2,449,734,526, unique=2,835
# ...processed 44200 files, total_hangul_chars=2,463,020,840, unique=2,835
# ...processed 44400 files, total_hangul_chars=2,476,788,479, unique=2,835
# ...processed 44600 files, total_hangul_chars=2,491,772,746, unique=2,835
# ...processed 44800 files, total_hangul_chars=2,506,425,144, unique=2,835
# ...processed 45000 files, total_hangul_chars=2,520,012,076, unique=2,835
# ...processed 45200 files, total_hangul_chars=2,534,666,386, unique=2,835
# ...processed 45400 files, total_hangul_chars=2,548,647,940, unique=2,835
# ...processed 45600 files, total_hangul_chars=2,561,579,050, unique=2,835
# ...processed 45800 files, total_hangul_chars=2,575,073,805, unique=2,835
# ...processed 46000 files, total_hangul_chars=2,584,473,894, unique=2,835
# ...processed 46200 files, total_hangul_chars=2,592,535,933, unique=2,835
# ...processed 46400 files, total_hangul_chars=2,601,688,211, unique=2,836
# ...processed 46600 files, total_hangul_chars=2,610,407,893, unique=2,836
# ...processed 46800 files, total_hangul_chars=2,618,634,451, unique=2,836
# ...processed 47000 files, total_hangul_chars=2,627,363,656, unique=2,836
# ...processed 47200 files, total_hangul_chars=2,636,606,768, unique=2,836
# ...processed 47400 files, total_hangul_chars=2,645,393,400, unique=2,836
# ...processed 47600 files, total_hangul_chars=2,652,978,734, unique=2,836
# ...processed 47800 files, total_hangul_chars=2,661,208,367, unique=2,837
# ...processed 48000 files, total_hangul_chars=2,669,723,096, unique=2,837
# ...processed 48200 files, total_hangul_chars=2,678,723,107, unique=2,838
# ...processed 48400 files, total_hangul_chars=2,688,120,927, unique=2,839
# ...processed 48600 files, total_hangul_chars=2,697,254,723, unique=2,839
# ...processed 48800 files, total_hangul_chars=2,708,793,451, unique=2,839
# ...processed 49000 files, total_hangul_chars=2,719,166,260, unique=2,839
# ...processed 49200 files, total_hangul_chars=2,729,655,863, unique=2,839
# ...processed 49400 files, total_hangul_chars=2,740,951,227, unique=2,839
# ...processed 49600 files, total_hangul_chars=2,752,214,291, unique=2,839
# ...processed 49800 files, total_hangul_chars=2,763,118,425, unique=2,839
# ...processed 50000 files, total_hangul_chars=2,774,338,824, unique=2,839
# ...processed 50200 files, total_hangul_chars=2,785,790,034, unique=2,839
# ...processed 50400 files, total_hangul_chars=2,797,576,864, unique=2,840
# ...processed 50600 files, total_hangul_chars=2,808,756,451, unique=2,841
# ...processed 50800 files, total_hangul_chars=2,823,763,669, unique=2,841
# ...processed 51000 files, total_hangul_chars=2,839,228,790, unique=2,841
# ...processed 51200 files, total_hangul_chars=2,855,373,692, unique=2,841
# ...processed 51400 files, total_hangul_chars=2,869,643,823, unique=2,841
# ...processed 51600 files, total_hangul_chars=2,882,768,206, unique=2,841
# ...processed 51800 files, total_hangul_chars=2,895,306,189, unique=2,841
#
# ===== SUMMARY =====
# Root: D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\030.웹데이터 기반 한국어 말뭉치 데이터\01.데이터\1.Training\라벨링데이터\TL1
# JSON files processed: 51830
# Total Hangul syllables: 2,897,148,355
# Unique Hangul syllables: 2,841
#
# ===== TOP 100 =====
# 이	102510161
# 다	87167692
# 는	55431489
# 에	53034922
# 을	50604076
# 지	44068838
# 의	43529279
# 고	43055826
# 로	40561031
# 한	38179350
# 가	37599052
# 기	35223904
# 하	34727948
# 은	31476123
# 대	30887047
# 서	30431716
# 사	29968803
# 를	29688551
# 시	28520255
# 자	27580857
# 해	27242863
# 도	25384676
# 인	24061703
# 전	23974561
# 수	22546022
# 했	21836021
# 원	21502000
# 스	21389685
# 정	21281814
# 일	21008154
# 리	20278791
# 으	20205346
# 장	19775585
# 부	19587423
# 름	18593922
# 있	17111187
# 과	17002514
# 상	16819333
# 국	16441063
# 제	16399602
# 주	15744704
# 아	15668264
# 보	15546051
# 라	15538814
# 어	14931054
# 만	13886631
# 공	13728598
# 나	13414069
# 위	13330924
# 들	12760840
# 회	12544905
# 적	12112236
# 성	12092585
# 재	11886296
# 관	11881272
# 업	11718281
# 등	11508450
# 구	11338293
# 소	11112265
# 비	11041591
# 경	10996587
# 선	10812594
# 면	10682314
# 중	10318103
# 동	10231384
# 게	10177954
# 진	10079177
# 개	10074087
# 계	9970360
# 조	9911722
# 화	9865802
# 것	9777469
# 무	9699176
# 신	9651220
# 며	9570549
# 통	9104472
# 금	9041882
# 그	8917546
# 단	8888242
# 와	8843182
# 트	8706507
# 명	8679147
# 내	8662932
# 당	8660805
# 행	8491156
# 연	8395287
# 할	8342006
# 유	8330129
# 문	8322862
# 여	8321071
# 안	8289891
# 년	8228274
# 산	8148733
# 오	8099053
# 우	7720705
# 용	7712588
# 모	7701361
# 마	7596662
# 발	7540534
# 방	7501653

# %%
HANGUL_BASE = 0xAC00
HANGUL_END  = 0xD7A3
N_CHO  = 19
N_JUNG = 21
N_JONG = 28

JUNG_LIST = [
    "ㅏ","ㅐ","ㅑ","ㅒ","ㅓ","ㅔ","ㅕ","ㅖ","ㅗ","ㅘ","ㅙ","ㅚ",
    "ㅛ","ㅜ","ㅝ","ㅞ","ㅟ","ㅠ","ㅡ","ㅢ","ㅣ"
]

VERTICAL_VOWELS = {"ㅏ","ㅐ","ㅑ","ㅒ","ㅓ","ㅔ","ㅕ","ㅖ","ㅣ"}  
HORIZONTAL_VOWELS = {"ㅗ","ㅛ","ㅜ","ㅠ","ㅡ"}          
MIX_VOWELS = {"ㅘ","ㅙ","ㅚ","ㅝ","ㅞ","ㅟ","ㅢ"}        

def decompose_syllable(ch: str) -> Optional[Tuple[int, int, int]]:
    if not ch or len(ch) != 1:
        return None
    code = ord(ch)
    if code < HANGUL_BASE or code > HANGUL_END:
        return None

    s_index = code - HANGUL_BASE
    cho = s_index // (N_JUNG * N_JONG)
    jung = (s_index % (N_JUNG * N_JONG)) // N_JONG
    jong = s_index % N_JONG
    return cho, jung, jong

def vowel_shape(jung_idx: int) -> str:
    v = JUNG_LIST[jung_idx]
    if v in VERTICAL_VOWELS:
        return "vertical"
    if v in HORIZONTAL_VOWELS:
        return "horizontal"
    if v in MIX_VOWELS:
        return "mix"
    return "unknown"

def classify_6group(ch: str) -> Optional[str]:
    dec = decompose_syllable(ch)
    if dec is None:
        return None
    _, jung, jong = dec
    vs = vowel_shape(jung)
    has_jong = (jong != 0)
    return f"{vs}_{'jong' if has_jong else 'no_jong'}"

# %%
def save_counter_with_6group_csv(
    counter, 
    out_csv: Path, 
    top_n: int = 1000,           
    save_all_groups_csv: bool = True
):
    out_csv = Path(out_csv)
    out_csv.parent.mkdir(parents=True, exist_ok=True)

    items = counter.most_common(top_n) if top_n else counter.most_common()

    rows = []
    for ch, cnt in items:
        grp = classify_6group(ch)
        if grp is None:
            continue
        dec = decompose_syllable(ch)
        _, jung, jong = dec
        rows.append({
            "char": ch,
            "count": cnt,
            "group6": grp,
            "vowel_shape": vowel_shape(jung),
            "has_jong": int(jong != 0),
            "jung_vowel": JUNG_LIST[jung],
        })

    with open(out_csv, "w", newline="", encoding="utf-8") as f:
        w = csv.DictWriter(
            f, 
            fieldnames=["char","count","group6","vowel_shape","has_jong","jung_vowel"]
        )
        w.writeheader()
        w.writerows(rows)

    print("Saved:", out_csv.resolve(), f"(rows={len(rows)})")

    if save_all_groups_csv:
        by_group = {}
        for r in rows:
            by_group.setdefault(r["group6"], []).append(r)

        for g, g_rows in by_group.items():
            g_path = out_csv.with_name(out_csv.stem + f"__{g}" + out_csv.suffix)
            with open(g_path, "w", newline="", encoding="utf-8") as f:
                w = csv.DictWriter(
                    f, 
                    fieldnames=["char","count","group6","vowel_shape","has_jong","jung_vowel"]
                )
                w.writeheader()
                w.writerows(g_rows)
            print("Saved group:", g_path.resolve(), f"(rows={len(g_rows)})")

# %%
out_csv = Path(r"D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\hangul_syllable_frequency_top1000.csv")

save_counter_with_6group_csv(
    counter=counter,
    out_csv=out_csv,
    top_n=None,                 # 상위 1000개만 저장. 전체 저장하려면 None
    save_all_groups_csv=True    # 그룹별 CSV도 따로 저장
)
# Out:
# Saved: D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\hangul_syllable_frequency_top1000.csv (rows=2841)
# Saved group: D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\hangul_syllable_frequency_top1000__vertical_no_jong.csv (rows=160)
# Saved group: D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\hangul_syllable_frequency_top1000__horizontal_jong.csv (rows=714)
# Saved group: D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\hangul_syllable_frequency_top1000__mix_no_jong.csv (rows=112)
# Saved group: D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\hangul_syllable_frequency_top1000__horizontal_no_jong.csv (rows=94)
# Saved group: D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\hangul_syllable_frequency_top1000__vertical_jong.csv (rows=1303)
# Saved group: D:\Study\학교강의\4학년2학기\캡스톤\Baram_Handwritting_Analysis\hangul_dataset\hangul_syllable_frequency_top1000__mix_jong.csv (rows=458)

# %%
save_top = None

rows = counter.most_common(save_top) if save_top else counter.most_common()

with open(out_csv, "w", newline="", encoding="utf-8") as f:
    w = csv.writer(f)
    w.writerow(["char", "count"])
    for ch, c in rows:
        w.writerow([ch, c])

print("Saved:", out_csv.resolve())
